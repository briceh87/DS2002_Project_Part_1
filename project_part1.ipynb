# %% [markdown]
# # Project 1: Mid-Term - ETL Processing

# %% [markdown]
# ### Pre-Processing Steps

# %% [markdown]
# #### Import the Necessary Libraries

# %%
import os
import json
import numpy
import datetime
import certifi
import pandas as pd

import pymongo
import sqlalchemy
from sqlalchemy import create_engine, text

# %%
print(f"Running SQL Alchemy Version: {sqlalchemy.__version__}")
print(f"Running PyMongo Version: {pymongo.__version__}")
# Out:
# Running SQL Alchemy Version: 2.0.38
# Running PyMongo Version: 4.11.2

# %% [markdown]
# #### Declare & Assign Connection Variables for the MongoDB Server, the MySQL Server & Working Databases

# %%
host_name = "localhost"
port = "3306"
user_id = "bhowe"
pwd = "Daufuskie1"

src_dbname = "adventureworks"
dst_dbname = "adventureworks_dw"

# -------------------------------------------------------------------------------------------------------------------------

# The 'cluster_location' is "atlas" for this project
mongodb_args = {
    "user_name" : "nkr7fg",
    "password" : "Daufuskie1",
    "cluster_name" : "ds2002",
    "cluster_subnet" : "zsrbu",
    "cluster_location" : "atlas",
    "db_name" : "adventureworks_sales"
}

# %% [markdown]
# #### Define Functions for Getting Data From and Setting Data Into Databases

# %%
def get_dataframe(user_id, pwd, host_name, db_name, sql_query):
    conn_str = f"mysql+pymysql://{user_id}:{pwd}@{host_name}/{db_name}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    dframe = pd.read_sql(sql_query, connection);
    connection.close()
    
    return dframe


def set_dataframe(user_id, pwd, host_name, db_name, df, table_name, pk_column, db_operation):
    conn_str = f"mysql+pymysql://{user_id}:{pwd}@{host_name}/{db_name}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    
    if db_operation == "insert":
        df.to_sql(table_name, con=connection, index=False, if_exists='replace')
        connection.execute(text(f"ALTER TABLE {table_name} ADD PRIMARY KEY ({pk_column});"))
            
    elif db_operation == "update":
        df.to_sql(table_name, con=connection, index=False, if_exists='append')
    
    connection.close()

# -----------------------------------------------------------------------------------------------------------------------------

def get_mongo_client(**args):
    '''Validate proper input'''
    if args["cluster_location"] not in ['atlas', 'local']:
        raise Exception("You must specify either 'atlas' or 'local' for the cluster_location parameter.")
    
    else:
        if args["cluster_location"] == "atlas":
            connect_str = f"mongodb+srv://{args['user_name']}:{args['password']}@"
            connect_str += f"{args['cluster_name']}.{args['cluster_subnet']}.mongodb.net"
            client = pymongo.MongoClient(connect_str, tlsCAFile=certifi.where())
            
        elif args["cluster_location"] == "local":
            client = pymongo.MongoClient("mongodb://localhost:27017/")
        
    return client


def get_mongo_dataframe(mongo_client, db_name, collection, query):
    '''Query MongoDB, and fill a python list with documents to create a DataFrame'''
    db = mongo_client[db_name]
    dframe = pd.DataFrame(list(db[collection].find(query)))
    dframe.drop(['_id'], axis=1, inplace=True)
    mongo_client.close()
    
    return dframe


def set_mongo_collections(mongo_client, db_name, data_directory, json_files):
    db = mongo_client[db_name]
    
    for file in json_files:
        db.drop_collection(file)
        json_file = os.path.join(data_directory, json_files[file])
        with open(json_file, 'r') as openfile:
            json_object = json.load(openfile)
            file = db[file]
            result = file.insert_many(json_object)
        
    mongo_client.close()

# %% [markdown]
# #### Create the New Data Warehouse Database ('adventureworks_dw') and Switch the Connection Context

# %%
conn_str = f"mysql+pymysql://{user_id}:{pwd}@{host_name}"
sqlEngine = create_engine(conn_str, pool_recycle=3600)
connection = sqlEngine.connect()

connection.execute(text(f"DROP DATABASE IF EXISTS `{dst_dbname}`;"))
connection.execute(text(f"CREATE DATABASE `{dst_dbname}`;"))
connection.execute(text(f"USE {dst_dbname};"))

connection.close()

# %% [markdown]
# #### Populate MongoDB with Source Data ('currencyrate')

# %%
client = get_mongo_client(**mongodb_args)

# Gets the path of the Current Working Directory for this Notebook,
# and then Appends the 'data' directory.
data_dir = os.path.join(os.getcwd(), 'data')

json_files = {"currencyrate" : 'currencyrate.json'}

set_mongo_collections(client, mongodb_args["db_name"], data_dir, json_files)

# %% [markdown]
# ### Create & Populate the Dimension Tables
# The ultimate goal is to create and populate a sales fact table that will reference surrogate primary key values from the 'customers', 'products', 'shipmethod', 'currencyrate', and 'salesperson' dimension tables. The first step towards creating this fact table is to populate these above dimension tables.
#
#
#
#
# #### Extract Data from the Source Database Table and Perform Necessary Transformations
# I am first fetching data for the 'customers', 'products', and 'salesperson' dimension tables from the **adventureworks** database using the **get_dataframe()** function. These dimensions will be extracted directly from MySQL. I then modify the tables by dropping features (columns) that do not provide any real value to the analytics solution. Then, I insert a new primary key column that contains an ever-increasing numeric value that is named after the entity (customer, product, salesperson) followed by "**_key**" to conform with data warehouse design standards.

# %% [markdown]
# Customers (Extracted from MySQL)

# %%
sql_customers = "SELECT * FROM adventureworks.customer;"
df_customers = get_dataframe(user_id, pwd, host_name, src_dbname, sql_customers)
df_customers.head(2)
# Out:
#    CustomerID  TerritoryID AccountNumber CustomerType  \
# 0           1            1    AW00000001            S
# 1           2            1    AW00000002            S
#
#                                           rowguid        ModifiedDate
# 0     b'^\xe9Z?}\xb8\xedJ\x95\xb4\xc3yz\xfc\xb7O' 2004-10-13 11:15:07
# 1  b'W\xf6R\xe5\xaf\xa9}J\xa6E\xc4)\xd6\xe0$\x91' 2004-10-13 11:15:07

# %%
# Drop unnecessary columns
drop_cols = ['rowguid','ModifiedDate']
df_customers.drop(drop_cols, axis=1, inplace=True)

# Insert a new column, with an ever-incrementing numeric value, to serve as the primary key.
df_customers.insert(0, "customer_key", range(1, df_customers.shape[0]+1))

df_customers.head(2)
# Out:
#    customer_key  CustomerID  TerritoryID AccountNumber CustomerType
# 0             1           1            1    AW00000001            S
# 1             2           2            1    AW00000002            S

# %% [markdown]
# Products (Extracted from MySQL)

# %%
sql_products = "SELECT * FROM adventureworks.product;"
df_products = get_dataframe(user_id, pwd, host_name, src_dbname, sql_products)
df_products.head(2)
# Out:
#    ProductID             Name ProductNumber MakeFlag FinishedGoodsFlag Color  \
# 0          1  Adjustable Race       AR-5381  b'\x00'           b'\x00'  None
# 1          2     Bearing Ball       BA-8327  b'\x00'           b'\x00'  None
#
#    SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ... ProductLine  \
# 0              1000           750           0.0        0.0  ...        None
# 1              1000           750           0.0        0.0  ...        None
#
#   Class Style  ProductSubcategoryID  ProductModelID SellStartDate SellEndDate  \
# 0  None  None                   NaN             NaN    1998-06-01         NaT
# 1  None  None                   NaN             NaN    1998-06-01         NaT
#
#   DiscontinuedDate                                            rowguid  \
# 0             None  b'\xb7\x15Bi\xf7\x08\rL\xac\xb1\xd74\xbaD\xc0\...
# 1             None              b' <\xaeX:OIG\xa7\xd4\xd5h\x80l\xc57'
#
#          ModifiedDate
# 0 2004-03-11 10:01:36
# 1 2004-03-11 10:01:36
#
# [2 rows x 25 columns]

# %%
# Drop unnecessary columns
drop_cols = ['MakeFlag','FinishedGoodsFlag','SellEndDate','DiscontinuedDate','SizeUnitMeasureCode',
             'WeightUnitMeasureCode','rowguid','ModifiedDate']
df_products.drop(drop_cols, axis=1, inplace=True)

# Insert a new column, with an ever-incrementing numeric value, to serve as the primary key.
df_products.insert(0, "product_key", range(1, df_products.shape[0]+1))

df_products.head(2)
# Out:
#    product_key  ProductID             Name ProductNumber Color  \
# 0            1          1  Adjustable Race       AR-5381  None
# 1            2          2     Bearing Ball       BA-8327  None
#
#    SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  Size  Weight  \
# 0              1000           750           0.0        0.0  None     NaN
# 1              1000           750           0.0        0.0  None     NaN
#
#    DaysToManufacture ProductLine Class Style  ProductSubcategoryID  \
# 0                  0        None  None  None                   NaN
# 1                  0        None  None  None                   NaN
#
#    ProductModelID SellStartDate
# 0             NaN    1998-06-01
# 1             NaN    1998-06-01

# %% [markdown]
# Sales Person (Extracted from MySQL)

# %%
sql_salesperson = "SELECT * FROM adventureworks.salesperson;"
df_salesperson = get_dataframe(user_id, pwd, host_name, src_dbname, sql_salesperson)
df_salesperson.head(2)
# Out:
#    SalesPersonID  TerritoryID  SalesQuota   Bonus  CommissionPct  \
# 0            268          NaN         NaN     0.0          0.000
# 1            275          2.0    300000.0  4100.0          0.012
#
#        SalesYTD  SalesLastYear                                      rowguid  \
# 0  6.775585e+05   0.000000e+00  b'\x92IuH\xe0\x9e\x0eL\x8c\x94\x94Q`N>\x02'
# 1  4.557045e+06   1.750406e+06          b'tr\n\x1ed0XO\x88\xeeLe\x86\xc8qi'
#
#   ModifiedDate
# 0   2001-01-28
# 1   2001-06-24

# %%
# Drop unnecessary columns
drop_cols = ['rowguid','ModifiedDate']
df_salesperson.drop(drop_cols, axis=1, inplace=True)

# Insert a new column, with an ever-incrementing numeric value, to serve as the primary key.
df_salesperson.insert(0, "salesperson_key", range(1, df_salesperson.shape[0]+1))

df_salesperson.head(2)
# Out:
#    salesperson_key  SalesPersonID  TerritoryID  SalesQuota   Bonus  \
# 0                1            268          NaN         NaN     0.0
# 1                2            275          2.0    300000.0  4100.0
#
#    CommissionPct      SalesYTD  SalesLastYear
# 0          0.000  6.775585e+05   0.000000e+00
# 1          0.012  4.557045e+06   1.750406e+06

# %% [markdown]
# Currency Rate (Extracted From MongoDB)

# %%
client = get_mongo_client(**mongodb_args)

query = {} # Select all elements (columns), and all documents (rows).
collection = "currencyrate"

df_currencyrate = get_mongo_dataframe(client, mongodb_args["db_name"], collection, query)
df_currencyrate.head(2)
# Out:
#    AverageRate  EndOfDayRate                ModifiedDate  CurrencyRateID  \
# 0       1.0000        1.0002  2001-07-01 00:00:00.000000               1
# 1       1.5491        1.5500  2001-07-01 00:00:00.000000               2
#
#   ToCurrencyCode FromCurrencyCode
# 0            ARS              USD
# 1            AUD              USD

# %%
drop_cols = ['ModifiedDate']
df_currencyrate.drop(drop_cols, axis=1, inplace=True)

# Insert a new column, with an ever-incrementing numeric value, to serve as the primary key.
df_currencyrate.insert(0, "currencyrate_key", range(1, df_currencyrate.shape[0]+1))

df_currencyrate.head(2)
# Out:
#    currencyrate_key  AverageRate  EndOfDayRate  CurrencyRateID ToCurrencyCode  \
# 0                 1       1.0000        1.0002               1            ARS
# 1                 2       1.5491        1.5500               2            AUD
#
#   FromCurrencyCode
# 0              USD
# 1              USD

# %% [markdown]
# Ship Method (Extracted From a Local CVS File)

# %%
column_names = ["ShipMethodID", "Name", "ShipBase", "ShipRate", "ModifiedDate"]

df_shipmethod = pd.read_csv(
    "C://Users//puckh//Desktop//Brice Documents//Fourth Year//DS Systems 2002//shipmethod.csv",
    names=column_names, 
    header=None)

df_shipmethod.head(2)
# Out:
#    ShipMethodID                Name  ShipBase  ShipRate         ModifiedDate
# 0             1  XRQ - TRUCK GROUND      3.95      0.99  1998-06-01 00:00:00
# 1             2        ZY - EXPRESS      9.95      1.99  1998-06-01 00:00:00

# %%
drop_cols = ['ModifiedDate']
df_shipmethod.drop(drop_cols, axis=1, inplace=True)

# Insert a new column, with an ever-incrementing numeric value, to serve as the primary key.
df_shipmethod.insert(0, "shipmethod_key", range(1, df_shipmethod.shape[0]+1))

df_shipmethod.head(2)
# Out:
#    shipmethod_key  ShipMethodID                Name  ShipBase  ShipRate
# 0               1             1  XRQ - TRUCK GROUND      3.95      0.99
# 1               2             2        ZY - EXPRESS      9.95      1.99

# %% [markdown]
# #### Load the Transformed DataFrames into "adventuresworks_dw" by Creating New Tables

# %%
db_operation = "insert"

tables = [('dim_customers', df_customers, 'customer_key'),
          ('dim_products', df_products, 'product_key'),
          ('dim_salesperson', df_salesperson, 'salesperson_key'),
          ('dim_shipmethod', df_shipmethod, 'shipmethod_key'),
          ('dim_currencyrate', df_currencyrate, 'currencyrate_key')
          ]

# %%
for table_name, dataframe, primary_key in tables:
    set_dataframe(user_id, pwd, host_name, dst_dbname, dataframe, table_name, primary_key, db_operation)

# %% [markdown]
# #### Create the Date Dimension Table
# Executed the script from earlier Lab 2c to create and populate a date dimension table (dim_date) that will be extracted from MySQL.

# %% [markdown]
# ### Create and Populate the Sales Fact Table

# %%
sql_sales_od = "SELECT * FROM adventureworks.salesorderdetail;"
df_sales_od = get_dataframe(user_id, pwd, host_name, src_dbname, sql_sales_od)
df_sales_od.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    ProductID  SpecialOfferID  UnitPrice  UnitPriceDiscount  LineTotal  \
# 0        776               1   2024.994                0.0   2024.994
# 1        777               1   2024.994                0.0   6074.982
#
#                                              rowguid ModifiedDate
# 0     b'm\xc9\x07\xb2\xe6\xd9+@\x84p,\xc1v\xc4"\x83'   2001-07-01
# 1  b'\r`\xbbzw\x1e\xbeA\x9f\xe5\xb9\x14,\xfc\x08\...   2001-07-01

# %%
drop_cols = ['rowguid','UnitPriceDiscount','ModifiedDate']
df_sales_od.drop(drop_cols, axis=1, inplace=True)

df_sales_od.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    ProductID  SpecialOfferID  UnitPrice  LineTotal
# 0        776               1   2024.994   2024.994
# 1        777               1   2024.994   6074.982

# %%
sql_sales_oh = "SELECT * FROM adventureworks.salesorderheader;"
df_sales_oh = get_dataframe(user_id, pwd, host_name, src_dbname, sql_sales_oh)
df_sales_oh.head(2)
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43659               1 2001-07-01 2001-07-13 2001-07-08       5
# 1         43660               1 2001-07-01 2001-07-13 2001-07-08       5
#
#   OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  ...  \
# 0         b'\x00'          SO43659         PO522145787  10-4020-000676  ...
# 1         b'\x00'          SO43660       PO18850127500  10-4020-000117  ...
#
#    CreditCardID  CreditCardApprovalCode  CurrencyRateID    SubTotal  \
# 0       16281.0           105041Vi84182             NaN  24643.9362
# 1        5618.0           115213Vi29411             NaN   1553.1035
#
#       TaxAmt   Freight    TotalDue  Comment  \
# 0  1971.5149  616.0984  27231.5495     None
# 1   124.2483   38.8276   1716.1794     None
#
#                                              rowguid  ModifiedDate
# 0  b'!S\xb6y\xca9\x15A\x9c\xba\x8f\xe0\x90>\x12\xe6'    2001-07-08
# 1        b'-\xc4\x8ds;\xd0\xa1H\x98"\xf9Zg\xeas\x89'    2001-07-08
#
# [2 rows x 27 columns]

# %%
drop_cols = ['rowguid','OnlineOrderFlag','Comment','ModifiedDate']
df_sales_oh.drop(drop_cols, axis=1, inplace=True)

df_sales_oh.head(2)
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43659               1 2001-07-01 2001-07-13 2001-07-08       5
# 1         43660               1 2001-07-01 2001-07-13 2001-07-08       5
#
#   SalesOrderNumber PurchaseOrderNumber   AccountNumber  CustomerID  ...  \
# 0          SO43659         PO522145787  10-4020-000676         676  ...
# 1          SO43660       PO18850127500  10-4020-000117         117  ...
#
#    BillToAddressID  ShipToAddressID  ShipMethodID  CreditCardID  \
# 0              985              985             5       16281.0
# 1              921              921             5        5618.0
#
#    CreditCardApprovalCode  CurrencyRateID    SubTotal     TaxAmt   Freight  \
# 0           105041Vi84182             NaN  24643.9362  1971.5149  616.0984
# 1           115213Vi29411             NaN   1553.1035   124.2483   38.8276
#
#      TotalDue
# 0  27231.5495
# 1   1716.1794
#
# [2 rows x 23 columns]

# %%
df_fact_sales = pd.merge(df_sales_od, df_sales_oh, on='SalesOrderID', how='inner')
df_fact_sales.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    ProductID  SpecialOfferID  UnitPrice  LineTotal  RevisionNumber  OrderDate  \
# 0        776               1   2024.994   2024.994               1 2001-07-01
# 1        777               1   2024.994   6074.982               1 2001-07-01
#
#    ... BillToAddressID ShipToAddressID  ShipMethodID CreditCardID  \
# 0  ...             985             985             5      16281.0
# 1  ...             985             985             5      16281.0
#
#   CreditCardApprovalCode CurrencyRateID    SubTotal     TaxAmt   Freight  \
# 0          105041Vi84182            NaN  24643.9362  1971.5149  616.0984
# 1          105041Vi84182            NaN  24643.9362  1971.5149  616.0984
#
#      TotalDue
# 0  27231.5495
# 1  27231.5495
#
# [2 rows x 30 columns]

# %% [markdown]
# #### Lookup the DateKeys from the Date Dimension Table.
# For each date typed column in the **sale** fact table, I lookup the corresponding Surrogate Primary Key column. I cast the date typed column to the **datetime64[ns]** data type using the **.astype()** function that is native to Pandas DataFrame columns and extract the **date** portion using the **.dt.date** attribute of the **datetime64[ns]** datatype.

# %%
sql_dim_date = "SELECT date_key, full_date FROM adventureworks_dw.dim_date;"
df_dim_date = get_dataframe(user_id, pwd, host_name, src_dbname, sql_dim_date)
df_dim_date.full_date = df_dim_date.full_date.astype('datetime64[ns]').dt.date
df_dim_date.head(2)
# Out:
#    date_key   full_date
# 0  20000101  2000-01-01
# 1  20000102  2000-01-02

# %%
# Lookup the Surrogate Primary Key (date_key) that Corresponds to the "OrderDate" Column.
df_dim_order_date = df_dim_date.rename(columns={"date_key" : "order_date_key", "full_date" : "OrderDate"})
df_fact_sales.OrderDate = df_fact_sales.OrderDate.astype('datetime64[ns]').dt.date

df_fact_sales = pd.merge(df_fact_sales, df_dim_order_date, on='OrderDate', how='left')
df_fact_sales.drop(['OrderDate'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    ProductID  SpecialOfferID  UnitPrice  LineTotal  RevisionNumber    DueDate  \
# 0        776               1   2024.994   2024.994               1 2001-07-13
# 1        777               1   2024.994   6074.982               1 2001-07-13
#
#    ... ShipToAddressID  ShipMethodID CreditCardID CreditCardApprovalCode  \
# 0  ...             985             5      16281.0          105041Vi84182
# 1  ...             985             5      16281.0          105041Vi84182
#
#   CurrencyRateID    SubTotal     TaxAmt   Freight    TotalDue  order_date_key
# 0            NaN  24643.9362  1971.5149  616.0984  27231.5495        20010701
# 1            NaN  24643.9362  1971.5149  616.0984  27231.5495        20010701
#
# [2 rows x 30 columns]

# %%
# Lookup the Surrogate Primary Key (date_key) that Corresponds to the "ShipDate" Column.
df_dim_ship_date = df_dim_date.rename(columns={"date_key" : "ship_date_key", "full_date" : "ShipDate"})
df_fact_sales.ShipDate = df_fact_sales.ShipDate.astype('datetime64[ns]').dt.date

df_fact_sales = pd.merge(df_fact_sales, df_dim_ship_date, on='ShipDate', how='left')
df_fact_sales.drop(['ShipDate'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    ProductID  SpecialOfferID  UnitPrice  LineTotal  RevisionNumber    DueDate  \
# 0        776               1   2024.994   2024.994               1 2001-07-13
# 1        777               1   2024.994   6074.982               1 2001-07-13
#
#    ...  ShipMethodID CreditCardID CreditCardApprovalCode CurrencyRateID  \
# 0  ...             5      16281.0          105041Vi84182            NaN
# 1  ...             5      16281.0          105041Vi84182            NaN
#
#      SubTotal     TaxAmt   Freight    TotalDue  order_date_key  ship_date_key
# 0  24643.9362  1971.5149  616.0984  27231.5495        20010701       20010708
# 1  24643.9362  1971.5149  616.0984  27231.5495        20010701       20010708
#
# [2 rows x 30 columns]

# %%
# Lookup the Surrogate Primary Key (date_key) that Corresponds to the "DueDate" Column.
df_dim_due_date = df_dim_date.rename(columns={"date_key" : "due_date_key", "full_date" : "DueDate"})
df_fact_sales.DueDate = df_fact_sales.DueDate.astype('datetime64[ns]').dt.date

df_fact_sales = pd.merge(df_fact_sales, df_dim_due_date, on='DueDate', how='left')
df_fact_sales.drop(['DueDate'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    ProductID  SpecialOfferID  UnitPrice  LineTotal  RevisionNumber  Status  \
# 0        776               1   2024.994   2024.994               1       5
# 1        777               1   2024.994   6074.982               1       5
#
#    ... CreditCardID CreditCardApprovalCode CurrencyRateID    SubTotal  \
# 0  ...      16281.0          105041Vi84182            NaN  24643.9362
# 1  ...      16281.0          105041Vi84182            NaN  24643.9362
#
#       TaxAmt   Freight    TotalDue  order_date_key  ship_date_key  \
# 0  1971.5149  616.0984  27231.5495        20010701       20010708
# 1  1971.5149  616.0984  27231.5495        20010701       20010708
#
#    due_date_key
# 0      20010713
# 1      20010713
#
# [2 rows x 30 columns]

# %% [markdown]
# #### Fetch the Surrogate Primary Key and the Business Key from Each Dimension Table

# %% [markdown]
# Customers

# %%
sql_dim_customers = "SELECT customer_key, CustomerID FROM adventureworks_dw.dim_customers;"
df_dim_customers = get_dataframe(user_id, pwd, host_name, src_dbname, sql_dim_customers)
df_dim_customers.head(2)
# Out:
#    customer_key  CustomerID
# 0             1           1
# 1             2           2

# %% [markdown]
# Products

# %%
sql_dim_products = "SELECT product_key, ProductID FROM adventureworks_dw.dim_products;"
df_dim_products = get_dataframe(user_id, pwd, host_name, src_dbname, sql_dim_products)
df_dim_products.head(2)
# Out:
#    product_key  ProductID
# 0            1          1
# 1            2          2

# %% [markdown]
# Sales Person

# %%
sql_dim_salesperson = "SELECT salesperson_key, SalesPersonID FROM adventureworks_dw.dim_salesperson;"
df_dim_salesperson = get_dataframe(user_id, pwd, host_name, src_dbname, sql_dim_salesperson)
df_dim_salesperson.head(2)
# Out:
#    salesperson_key  SalesPersonID
# 0                1            268
# 1                2            275

# %% [markdown]
# Ship Method

# %%
sql_dim_shipmethod = "SELECT shipmethod_key, ShipMethodID FROM adventureworks_dw.dim_shipmethod;"
df_dim_shipmethod = get_dataframe(user_id, pwd, host_name, src_dbname, sql_dim_shipmethod)
df_dim_shipmethod.head(2)
# Out:
#    shipmethod_key  ShipMethodID
# 0               1             1
# 1               2             2

# %% [markdown]
# Currency Rate

# %%
sql_dim_currencyrate = "SELECT currencyrate_key, CurrencyRateID FROM adventureworks_dw.dim_currencyrate;"
df_dim_currencyrate = get_dataframe(user_id, pwd, host_name, src_dbname, sql_dim_currencyrate)
df_dim_currencyrate.head(2)
# Out:
#    currencyrate_key  CurrencyRateID
# 0                 1               1
# 1                 2               2

# %% [markdown]
# #### Use the Business Keys to lookup the corresponding Surrogate Primary Key values in the Dimension tables

# %% [markdown]
# Customers

# %%
# 1. Modify 'df_fact_sales' by merging it with 'df_dim_customers' on the 'CustomerID' column
# 2. Drop the 'CustomerID' column
df_fact_sales = pd.merge(df_fact_sales, df_dim_customers, on='CustomerID', how='left')
df_fact_sales.drop(['CustomerID'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    ProductID  SpecialOfferID  UnitPrice  LineTotal  RevisionNumber  Status  \
# 0        776               1   2024.994   2024.994               1       5
# 1        777               1   2024.994   6074.982               1       5
#
#    ... CreditCardApprovalCode CurrencyRateID    SubTotal     TaxAmt   Freight  \
# 0  ...          105041Vi84182            NaN  24643.9362  1971.5149  616.0984
# 1  ...          105041Vi84182            NaN  24643.9362  1971.5149  616.0984
#
#      TotalDue  order_date_key  ship_date_key  due_date_key  customer_key
# 0  27231.5495        20010701       20010708      20010713           676
# 1  27231.5495        20010701       20010708      20010713           676
#
# [2 rows x 30 columns]

# %% [markdown]
# Products

# %%
# 1. Modify 'df_fact_sales' by merging it with 'df_dim_products' on the 'ProductID' column
# 2. Drop the 'ProductID' column
df_fact_sales = pd.merge(df_fact_sales, df_dim_products, on='ProductID', how='left')
df_fact_sales.drop(['ProductID'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    SpecialOfferID  UnitPrice  LineTotal  RevisionNumber  Status  \
# 0               1   2024.994   2024.994               1       5
# 1               1   2024.994   6074.982               1       5
#
#   SalesOrderNumber  ... CurrencyRateID    SubTotal     TaxAmt   Freight  \
# 0          SO43659  ...            NaN  24643.9362  1971.5149  616.0984
# 1          SO43659  ...            NaN  24643.9362  1971.5149  616.0984
#
#      TotalDue  order_date_key  ship_date_key  due_date_key  customer_key  \
# 0  27231.5495        20010701       20010708      20010713           676
# 1  27231.5495        20010701       20010708      20010713           676
#
#   product_key
# 0         281
# 1         282
#
# [2 rows x 30 columns]

# %% [markdown]
# Sales Person

# %%
# 1. Modify 'df_fact_sales' by merging it with 'df_dim_salesperson' on the 'SalesPersonID' column
# 2. Drop the 'SalesPersonID' column
df_fact_sales = pd.merge(df_fact_sales, df_dim_salesperson, on='SalesPersonID', how='left')
df_fact_sales.drop(['SalesPersonID'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    SpecialOfferID  UnitPrice  LineTotal  RevisionNumber  Status  \
# 0               1   2024.994   2024.994               1       5
# 1               1   2024.994   6074.982               1       5
#
#   SalesOrderNumber  ...    SubTotal     TaxAmt   Freight    TotalDue  \
# 0          SO43659  ...  24643.9362  1971.5149  616.0984  27231.5495
# 1          SO43659  ...  24643.9362  1971.5149  616.0984  27231.5495
#
#    order_date_key  ship_date_key  due_date_key  customer_key product_key  \
# 0        20010701       20010708      20010713           676         281
# 1        20010701       20010708      20010713           676         282
#
#    salesperson_key
# 0              6.0
# 1              6.0
#
# [2 rows x 30 columns]

# %% [markdown]
# Ship Method

# %%
# 1. Modify 'df_fact_sales' by merging it with 'df_dim_shipmethod' on the 'ShipMethodID' column
# 2. Drop the 'ShipMethodID' column
df_fact_sales = pd.merge(df_fact_sales, df_dim_shipmethod, on='ShipMethodID', how='left')
df_fact_sales.drop(['ShipMethodID'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    SpecialOfferID  UnitPrice  LineTotal  RevisionNumber  Status  \
# 0               1   2024.994   2024.994               1       5
# 1               1   2024.994   6074.982               1       5
#
#   SalesOrderNumber  ...     TaxAmt   Freight    TotalDue  order_date_key  \
# 0          SO43659  ...  1971.5149  616.0984  27231.5495        20010701
# 1          SO43659  ...  1971.5149  616.0984  27231.5495        20010701
#
#    ship_date_key  due_date_key  customer_key product_key  salesperson_key  \
# 0       20010708      20010713           676         281              6.0
# 1       20010708      20010713           676         282              6.0
#
#    shipmethod_key
# 0               5
# 1               5
#
# [2 rows x 30 columns]

# %% [markdown]
# Currency Rate

# %%
# 1. Modify 'df_fact_sales' by merging it with 'df_dim_currencyrate' on the 'CurrencyRateID' column
# 2. Drop the 'CurrencyRateID' column
df_fact_sales = pd.merge(df_fact_sales, df_dim_currencyrate, on='CurrencyRateID', how='left')
df_fact_sales.drop(['CurrencyRateID'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    SpecialOfferID  UnitPrice  LineTotal  RevisionNumber  Status  \
# 0               1   2024.994   2024.994               1       5
# 1               1   2024.994   6074.982               1       5
#
#   SalesOrderNumber  ...   Freight    TotalDue  order_date_key  ship_date_key  \
# 0          SO43659  ...  616.0984  27231.5495        20010701       20010708
# 1          SO43659  ...  616.0984  27231.5495        20010701       20010708
#
#    due_date_key  customer_key  product_key salesperson_key  shipmethod_key  \
# 0      20010713           676          281             6.0               5
# 1      20010713           676          282             6.0               5
#
#    currencyrate_key
# 0               NaN
# 1               NaN
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Perform Final Transformations to the DataFrame

# %%
# Drop the columns of no particular interest
drop_cols = ['SpecialOfferID', 'RevisionNumber',  'SalesOrderNumber', 'CarrierTrackingNumber','PurchaseOrderNumber', 
             'AccountNumber', 'BillToAddressID', 'ShipToAddressID','CreditCardApprovalCode']
df_fact_sales.drop(drop_cols,axis=1,inplace=True)

df_fact_sales.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID  OrderQty  UnitPrice  LineTotal  Status  \
# 0         43659                   1         1   2024.994   2024.994       5
# 1         43659                   2         3   2024.994   6074.982       5
#
#    ContactID  TerritoryID  CreditCardID    SubTotal  ...   Freight  \
# 0        378            5       16281.0  24643.9362  ...  616.0984
# 1        378            5       16281.0  24643.9362  ...  616.0984
#
#      TotalDue  order_date_key  ship_date_key  due_date_key  customer_key  \
# 0  27231.5495        20010701       20010708      20010713           676
# 1  27231.5495        20010701       20010708      20010713           676
#
#    product_key  salesperson_key  shipmethod_key  currencyrate_key
# 0          281              6.0               5               NaN
# 1          282              6.0               5               NaN
#
# [2 rows x 21 columns]

# %%
# Reorder the remaining columns
order_of_cols = ['SalesOrderID', 'SalesOrderDetailID', 'customer_key', 'product_key', 
                 'salesperson_key', 'shipmethod_key', 'currencyrate_key','order_date_key', 
                 'ship_date_key','due_date_key','ContactID', 'TerritoryID', 'CreditCardID',
                 'OrderQty', 'UnitPrice', 'LineTotal','SubTotal', 'TaxAmt', 
                 'Freight', 'TotalDue','Status']
df_fact_sales = df_fact_sales[order_of_cols]

# Insert a new column, with an ever-incrementing numeric value, to serve as the primary key.
df_fact_sales.insert(0, 'fact_sales_key', range(1,df_fact_sales.shape[0]+1))

df_fact_sales.head(2)
# Out:
#    fact_sales_key  SalesOrderID  SalesOrderDetailID  customer_key  \
# 0               1         43659                   1           676
# 1               2         43659                   2           676
#
#    product_key  salesperson_key  shipmethod_key  currencyrate_key  \
# 0          281              6.0               5               NaN
# 1          282              6.0               5               NaN
#
#    order_date_key  ship_date_key  ...  TerritoryID  CreditCardID  OrderQty  \
# 0        20010701       20010708  ...            5       16281.0         1
# 1        20010701       20010708  ...            5       16281.0         3
#
#    UnitPrice  LineTotal    SubTotal     TaxAmt   Freight    TotalDue  Status
# 0   2024.994   2024.994  24643.9362  1971.5149  616.0984  27231.5495       5
# 1   2024.994   6074.982  24643.9362  1971.5149  616.0984  27231.5495       5
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Load the Sales Fact Table into the AdventureWorks_DW Data Warehouse

# %%
table_name = "fact_sales"
primary_key = "fact_sales_key"
db_operation = "insert"

set_dataframe(user_id, pwd, host_name, dst_dbname, df_fact_sales, table_name, primary_key, db_operation)

# %% [markdown]
# ### SQL Queries

# %% [markdown]
# #### Query 1
# Sales Revenue by Product Category:  This query joins fact_sales, dim_products, and dim_date to evaluate revenue trends across different products

# %%
sql_test1 = """
    SELECT 
        d.calendar_year AS Year, 
        p.Name AS Product_Name, 
        SUM(fs.LineTotal) AS Total_Sales
    FROM `{0}`.fact_sales AS fs
    JOIN `{0}`.dim_products AS p 
    ON fs.product_key = p.product_key
    JOIN `{0}`.dim_date AS d 
    ON fs.order_date_key = d.date_key
    GROUP BY d.calendar_year, p.Name
    ORDER BY Total_Sales DESC;

""".format(dst_dbname)

df_test = get_dataframe(user_id, pwd, host_name, src_dbname, sql_test1)
df_test.head(20)
# Out:
#     Year             Product_Name   Total_Sales
# 0   2003   Mountain-200 Black, 38  2.176124e+06
# 1   2003   Mountain-200 Black, 42  1.935147e+06
# 2   2003  Mountain-200 Silver, 38  1.792442e+06
# 3   2003   Mountain-200 Black, 46  1.616099e+06
# 4   2003  Mountain-200 Silver, 46  1.598389e+06
# 5   2003  Mountain-200 Silver, 42  1.567267e+06
# 6   2004   Mountain-200 Black, 38  1.327957e+06
# 7   2003       Road-250 Black, 44  1.280263e+06
# 8   2003       Road-250 Black, 48  1.169568e+06
# 9   2004   Mountain-200 Black, 42  1.139429e+06
# 10  2004  Mountain-200 Silver, 38  1.136622e+06
# 11  2004  Mountain-200 Silver, 46  1.029171e+06
# 12  2004  Mountain-200 Silver, 42  1.011486e+06
# 13  2004   Mountain-200 Black, 46  1.011074e+06
# 14  2003       Road-250 Black, 52  1.004374e+06
# 15  2002         Road-150 Red, 56  9.790147e+05
# 16  2002         Road-150 Red, 62  9.410850e+05
# 17  2002   Mountain-200 Black, 42  9.349180e+05
# 18  2004    Road-350-W Yellow, 48  8.972180e+05
# 19  2002   Mountain-200 Black, 38  8.965116e+05

# %% [markdown]
# #### Query 2
# Shipping Method Preferences by Customer ID:  This query joins fact_sales, dim_customers, and dim_shipmethod to determine which shipping methods customers prefer

# %%
sql_test2 = """
    SELECT 
        c.CustomerID, 
        sm.Name AS ShipMethodName, 
        COUNT(fs.SalesOrderID) AS total_orders, 
        SUM(fs.LineTotal) AS total_spent
    FROM `{0}`.fact_sales AS fs
    JOIN `{0}`.dim_customers AS c 
    ON fs.customer_key = c.customer_key
    JOIN `{0}`.dim_shipmethod AS sm 
    ON fs.shipmethod_key = sm.shipmethod_key
    GROUP BY c.CustomerID, sm.Name
    ORDER BY total_spent DESC;
""".format(dst_dbname)

df_test = get_dataframe(user_id, pwd, host_name, src_dbname, sql_test2)
df_test.head(20)
# Out:
#     CustomerID     ShipMethodName  total_orders    total_spent
# 0          697  CARGO TRANSPORT 5           298  877107.192221
# 1          170  CARGO TRANSPORT 5           366  853849.179524
# 2          678  CARGO TRANSPORT 5           530  841908.770707
# 3          328  CARGO TRANSPORT 5           436  816755.576276
# 4          514  CARGO TRANSPORT 5           451  799277.895062
# 5          155  CARGO TRANSPORT 5           429  787773.043768
# 6           72  CARGO TRANSPORT 5           332  746317.529257
# 7          433  CARGO TRANSPORT 5           358  740985.833742
# 8          227  CARGO TRANSPORT 5           352  730798.713914
# 9          166  CARGO TRANSPORT 5           336  727272.649367
# 10         146  CARGO TRANSPORT 5           332  724299.636471
# 11         670  CARGO TRANSPORT 5           312  711864.762447
# 12         506  CARGO TRANSPORT 5           290  700803.785335
# 13         167  CARGO TRANSPORT 5           422  693502.485224
# 14         546  CARGO TRANSPORT 5           357  671618.029459
# 15         638  CARGO TRANSPORT 5           405  643745.895824
# 16          24  CARGO TRANSPORT 5           401  636226.469980
# 17         309  CARGO TRANSPORT 5           393  618616.128152
# 18         436  CARGO TRANSPORT 5           371  617340.457924
# 19         496  CARGO TRANSPORT 5           441  602559.892568
